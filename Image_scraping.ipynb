# %%
import selenium
from selenium import webdriver
from selenium .webdriver.common.by import By
 
import warnings 
warnings.filterwarnings("ignore")

# %%
driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (2)\chromedriver.exe')

url='https://www.amazon.in/'
driver.get(url)

# %%
for _ in range(300):
    driver.execute_script("window.scrollBy(0,1000)")

# %% [markdown]
#                                                SAREES

# %%
search_bar = driver.find_element(By.ID,"twotabsearchtextbox")
search_bar.send_keys("Sarees")

search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search.click()

# %%
images=driver.find_elements(By.XPATH,'//img[@class="s-image"]')
img=[]
for image in images:
    source=image.get_attribute('src')

    if source is not None:
        if(source[0:4]=='http'):
            img.append(source)

# %%
for i in range(len(img)):
    if i > 75:
        break
    print("Downloading {0} of {1} images" .format(i,75))
    response=requests.get(img[i])
    file = open(r"imagee"+str(i)+".jpg","wb")
    file.write(response.content)

# %% [markdown]
#                                                  TROUSER

# %%
search_bar = driver.find_element(By.ID,"twotabsearchtextbox")
search_bar.send_keys("Mens Trouser")

search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search.click()

# %%
images=driver.find_elements(By.XPATH,'//img[@class="s-image"]')
img=[]
for image in images:
    source=image.get_attribute('src')

    if source is not None:
        if(source[0:4]=='http'):
            img.append(source)

# %%
for i in range(len(img)):
    if i > 67:
        break
    print("Downloading {0} of {1} images" .format(i,67))
    response=requests.get(img[i])
    file = open(r"imagee"+str(i)+".jpg","wb")
    file.write(response.content)

# %% [markdown]
#                                                 JEANS

# %%
search_bar = driver.find_element(By.ID,"twotabsearchtextbox")
search_bar.send_keys("Mens Jeans")

search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search.click()

# %%
images=driver.find_elements(By.XPATH,'//img[@class="s-image"]')
img=[]
for image in images:
    source=image.get_attribute('src')

    if source is not None:
        if(source[0:4]=='http'):
            img.append(source)

# %%
for i in range(len(img)):
    if i > 72:
        break
    print("Downloading {0} of {1} images" .format(i,72))
    response=requests.get(img[i])
    file = open(r"imagee"+str(i)+".jpg","wb")
    file.write(response.content)
